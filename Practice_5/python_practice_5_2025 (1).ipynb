# %% [markdown]
# # I. OOP

# %% [markdown]
# 1. (6б). Створіть клас Building, додайте три атрибути, один з яких має значення за замовчуванням та два методи на свій розсуд.

# %%
class Building:
  def __init__(self, address, floors, material = "brick"):
    self.address = address
    self.floors = floors
    self.material = material
  def info(self):
    return f"Address: {self.address}, floors: {self.floors}, materials: {self.material}"
  def add_floor(self):
    self.floors += 1

# %% [markdown]
# 2. (2б). Створіть два обʼєкти цього класу, де один з обʼєктів створюється із дефолтним значенням атрибуту. На одному обʼєкті отримайте значення його атрибуту, а на іншому викличте один з його методів.

# %%
building1 = Building("Kyiv, Shevchenka 1", 5)
building2 = Building("Odesa, Bulvarna 4", 7)
print(building1.info())
building2.add_floor()
print(building2.info())
# Out:
# Address: Kyiv, Shevchenka 1, floors: 5, materials: brick
# Address: Odesa, Bulvarna 4, floors: 8, materials: brick

# %% [markdown]
# 3. (5б). Створіть клас, де атрибути мають різні рівні доступу. Спробуйте отримати їхні значення та опишіть результати.

# %%
class Access:
  def __init__(self):
    self.public = 1
    self._protected = 2
    self.__private = 3
a = Access()
print(a.public)
print(a._protected)
#print(a.__private)
print(a._Access__private)
# Out:
# 1
# 2
# 3

# %% [markdown]
# 4. (7б). Як ви розумієте термін self? Для чого використовується метод __init __?

# %% [markdown]
# self це посислання на конкретний обєкт, через self ми зберігаємо та/або читаємо його дані (наприклад self.value)
#
# __init__ це метод, який запускається при створенні обєкта і задає початкові значення атрибутів

# %% [markdown]
# 5. (9б). Створіть клас 3D-фігура без атрибутів, з методом get_volume для отримання об'єму фігури, що повертає 0 та __add __, який приймає self та other в якості аргументів, а повертає суму об'ємів 3d-фігур self та other.

# %%
class Shape3D:
  def get_volume(self):
    return 0
  def __add__(self, other):
    return self.get_volume() + other.get_volume()

# %% [markdown]
# 6. (11б). Створіть 2 дочірніх класи від 3d-фігура: Циліндр та Куб, які мають атрибути, необхідні для розрахунку об'єму. Визначте метод get_volume в кожному з них так, щоби вони розраховували об'єм у залежності від формули для кожного типу фігури. Створіть обʼєкт класу Циліндр та обʼєкт класу Куб. Виконайте операцію суми за допомогою оператора + між ними, аби знайти сумарний об'єм.

# %%
class Cylinder(Shape3D):
  def __init__(self, r, h):
    self.r = r
    self.h = h
  def get_volume(self):
    pi = 3.1415
    return pi * (self.r ** 2) * self.h

class Cube(Shape3D):
  def __init__(self, a):
    self.a = a
  def get_volume(self):
    return self.a ** 3

cyl = Cylinder(2, 5)
qb = Cube(4)
total = cyl + qb
print("Cylinder volume: ", cyl.get_volume())
print("Cube volume: ", qb.get_volume())
print("Total volume: ", total)
# Out:
# Cylinder volume:  62.830000000000005
# Cube volume:  64
# Total volume:  126.83000000000001

# %% [markdown]
# 7. (3б). Продемонструйте різницю між isinstance та issubclass.

# %%
print(isinstance(cyl, Cylinder))  # True (cyl - об'єкт Cylinder)
print(isinstance(cyl, Shape3D))   # True (Cylinder наслідує Shape3D)

print(issubclass(Cylinder, Shape3D))  # True (клас Cylinder є підкласом Shape3D)
print(issubclass(Cube, Shape3D))      # True
# print(issubclass(cyl, Shape3D))     # ERROR, бо issubclass вимагає клас, а не об'єкт
# Out:
# True
# True
# True
# True

# %% [markdown]
# 8. (13б). Створіть клас EWallet з приватними атрибутами balance та id. Реалізуйте методи поповнення та зняття коштів, забезпечивши належну інкапсуляцію. Підказка: використовуйте декоратори property та setter.

# %%
class EWallet:
  def __init__(self, balance, id):
    self.balance = balance
    self._id = id
  @property
  def balance(self):
    return self._balance
  @balance.setter
  def balance(self, value):
    if value < 0: raise ValueError("balance cannot be negative")
    self._balance = value


wallet = EWallet(15, 1)
wallet._id
wallet.balance =-1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-799099591.py in <cell line: 0>()
#      14 wallet = EWallet(15, 1)
#      15 wallet._id
# ---> 16 wallet.balance =-1
#
# /tmp/ipython-input-799099591.py in balance(self, value)
#       8   @balance.setter
#       9   def balance(self, value):
# ---> 10     if value < 0: raise ValueError("balance cannot be negative")
#      11     self._balance = value
#      12
#
# ValueError: balance cannot be negative

# %% [markdown]
# 9. (11б). Створіть клас ShoppingCart, який містить список об'єктів типу Item. Реалізуйте методи для додавання айтемів, їх видалення та відображення списку айтемів.

# %%
class Item:
  def __init__(self, name):
    self.name = name

class ShoppingCart:
  def __init__(self, items):
    self.items = items

  def print(self):
    res = ""
    for item in self.items:
      res += f"{item.name},"
    print(res)

our_list = list((Item("item1"), Item("item2")))
cart = ShoppingCart(our_list)
print(cart)
cart.print()
# Out:
# ...
# item1,item2,

# %% [markdown]
# 10. (13б). Створіть клас Vehicle з атрибутами brand (manufacturer) та production_age. Створіть ще один клас Engine з такими атрибутами, як type (ex. petrol) та size (volume, litres). Створіть клас Car, який успадковує обидва класи Vehicle та Engine. Продемонструйте використання множинної спадковості, створивши обʼєкт класу Car та отримавши mro для цього класу.

# %%
class Vehicle:
    def __init__(self, brand, production_age):
        self.brand = brand
        self.production_age = production_age
class Engine:
    def __init__(self, type, size):
        self.type = type
        self.size = size
class Car(Vehicle, Engine):
    def __init__(self, brand, production_age, type, size):
        Vehicle.__init__(self, brand, production_age)
        Engine.__init__(self, type, size)

car = Car("Audi", 5, "petrol", 2.0)
print(car.brand, car.production_age)
print(car.type, car.size)
print(Car.mro())
# Out:
# Audi 5
# petrol 2.0
# [<class '__main__.Car'>, <class '__main__.Vehicle'>, <class '__main__.Engine'>, <class 'object'>]

# %% [markdown]
# # II. Iterator

# %% [markdown]
# 11. (4б). Визначте рядок(str) з 4ма різними за значенням символами. Створіть ітератор на основі цього рядка. Викличте 5 разів функцію next на ітераторі, 4ри перших з них огорніть у ф-цію print().

# %%
s = "aB7!"
it = iter(s)
print(next(it))
print(next(it))
print(next(it))
print(next(it))
print(next(it, "Stop"))
# Out:
# a
# B
# 7
# !
# Stop

# %% [markdown]
# А що якщо викликати цю ж функцію на рядку?

# %%
next(s)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1977886155.py in <cell line: 0>()
# ----> 1 next(s)
#
# TypeError: 'str' object is not an iterator

# %% [markdown]
# Так не можна, оскільки рядок iterable, а iterator - ні
# Як альтернатива, можна написати print(next(iter(s)))

# %% [markdown]
#  12. (5б). Опишіть своїми словами в одному реченні, як ви розумієте різницю між ітерабельними обʼєктами та ітераторами (можна на прикладі).

# %% [markdown]
# Iterable це обєкт по якому можна почати ітеруватись, а iterator це той, у кого є __next__() і хто видає елементи по одному через next()

# %% [markdown]
# 13. (11б). Створіть клас, що має визначений Iterator Protocol та при кожному виклику next повертає назву дня тижня, поки вони не вичерпаються. Зверніть увагу, що порядок має значення.

# %%
class WeekIterator:
    def __init__(self):
        self.days = ["Mon", "Tue", "Wed", "Thu", "Fri", "Sat", "Sun"]
        self.i = 0
    def __iter__(self):
        return self
    def __next__(self):
        if self.i >= len(self.days):
            raise StopIteration
        day = self.days[self.i]
        self.i += 1
        return day
w = WeekIterator()
print(next(w))
print(next(w))
print(next(w))
for d in WeekIterator():
    print(d)
# Out:
# Mon
# Tue
# Wed
# Mon
# Tue
# Wed
# Thu
# Fri
# Sat
# Sun

# %% [markdown]
# # Вітаю! Ви велика(ий) молодець, що впоралась(вся). Похваліть себе та побалуйте чимось приємним. Я Вами пишаюся.

# %%
class A:
  def __init__(self, value):
    self.value = value
  def print(self):
    print(f"Hello (self.value)")

class B(A):
  def __init__(self, value):
    self.value = value
  #def print(self):
   # print("Hello B!")

class C(B):
  def __init__(self):
    pass
  def print(self):
    print("Hello C!")

print(A.__mro__)
print(B.__mro__)
print(C.__mro__)
a = A(123)
b = B(456)
c = C()
a.print()
b.print()
c.print()
# Out:
# (<class '__main__.A'>, <class 'object'>)
# (<class '__main__.B'>, <class '__main__.A'>, <class 'object'>)
# (<class '__main__.C'>, <class '__main__.B'>, <class '__main__.A'>, <class 'object'>)
# Hello (self.value)
# Hello (self.value)
# Hello C!

# %%
class Class:
  #def __new__(cls):
   # print("Hi")
    #return super(Class, cls).__new__(cls)

  def __init__(self, value):
    self.value = value
    print("Bye")

  def print(self):
      print(self.value)

class SecondClass(Class):
  def __init__(self, value = 0):
    super().__init__(value)
    print("See u")

a = Class(10)
print(a)
SecCl = SecondClass()
print(SecCl)
# Out:
# Bye
# ...
# Bye
# See u
# ...
